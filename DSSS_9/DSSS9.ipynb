# %% [markdown]
# <a href="https://colab.research.google.com/github/abhik718/DSSS_9/blob/main/DSSS9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install FlickrAPI
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 3.2 MB/s eta 0:00:00
# ...

# %%
from  flickrapi import FlickrAPI
import requests
from PIL import Image
from io import BytesIO

# %%
key = "2b081755d543dda8451684344ba6f96a"
secret = "73feccb1954a5937"

# %%
flickr = FlickrAPI(key, secret, format='etree')

# %%
keyword = ["dog", "cat", "ape"]

for i in keyword:
  	photos = flickr.walk(text=keyword[i],
                     tag_mode='all',
                     tags=keyword[i],
                     extras='url_c',
                     per_page=100,
                     sort='relevance')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-6067ef9896e4> in <module>
#       2
#       3 for i in keyword:
# ----> 4   	photos = flickr.walk(text=keyword[i],
#       5                      tag_mode='all',
#       6                      tags=keyword[i],
#
# TypeError: list indices must be integers or slices, not str

# %%
keyword1 = "dog"

photos1 = flickr.walk(text=keyword1,
                     tag_mode='all',
                     tags=keyword1,
                     extras='url_c',
                     per_page=100,
                     sort='relevance')

keyword2 = "cat"
photos2 = flickr.walk(text=keyword2,
                     tag_mode='all',
                     tags=keyword2,
                     extras='url_c',
                     per_page=100,
                     sort='relevance')

keyword3 = "ape"
photos3 = flickr.walk(text=keyword3,
                     tag_mode='all',
                     tags=keyword3,
                     extras='url_c',
                     per_page=100,
                     sort='relevance')

# %%
# keyword2 = "cat"
# photos2 = flickr.walk(text=keyword2,
#                      tag_mode='all',
#                      tags=keyword2,
#                      extras='url_c',
#                      per_page=100,
#                      sort='relevance')

# %%
# keyword3 = "ape"
# photos3 = flickr.walk(text=keyword3,
#                      tag_mode='all',
#                      tags=keyword3,
#                      extras='url_c',
#                      per_page=100,
#                      sort='relevance')

# %%
# urls_dogs = []
# for i, photo in enumerate(photos1):
#     urls_dogs.append(photo.get('url_c'))

#     if i == 10:
#         break

# urls_cats = []
# for i, photo in enumerate(photos2):
#     urls_cats.append(photo.get('url_c'))

#     if i == 10:
#         break

# urls_apes = []
# for i, photo in enumerate(photos3):
#     urls_apes.append(photo.get('url_c'))

#     if i == 10:
#         break

# %%
# urls_cats = []
# for i, photo in enumerate(photos2):
#     urls_cats.append(photo.get('url_c'))

#     if i == 10:
#         break

# %%
# urls_apes = []
# for i, photo in enumerate(photos3):
#     urls_apes.append(photo.get('url_c'))

#     if i == 10:
#         break

# %%
urls_dogs = []
for i, photo in enumerate(photos1):
  if (photo.get('url_c') != None):
    urls_dogs.append(photo.get('url_c'))

    if i == 1200:
        break

# %%
urls_cats = []
for i, photo in enumerate(photos2):
  if (photo.get('url_c') != None):
    urls_cats.append(photo.get('url_c'))

    if i == 1200:
        break

# %%
urls_apes = []
for i, photo in enumerate(photos3):
  if (photo.get('url_c') != None):
    urls_apes.append(photo.get('url_c'))

    if i == 1200:
        break

# %%
len(urls_dogs)
# Out:
# 1132

# %%
# for i in range (1000):
#   if(urls_dogs[i] == None):
#     print('failed')
#   else:
#     print('success')

# %%
len(urls_cats)
# Out:
# 1142

# %%
len(urls_apes)
# Out:
# 1127

# %%
import urllib.request
import os
from pathlib import Path

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = r'C:\\Users\abhik\Downloads\EX9 DATA SCIENCE\imagedca'

# %%
for i in range(1000):
    urllib.request.urlretrieve(urls_dogs[i],path + '\{0}_{1}.jpg'.format(keyword1 ,i))
    urllib.request.urlretrieve(urls_cats[i],path + '\{0}_{1}.jpg'.format(keyword2 ,i))
    urllib.request.urlretrieve(urls_apes[i],path + '\{0}_{1}.jpg'.format(keyword3 ,i))

# %%
for i in range(1000):
    image1 = Image.open(path + '\{0}_{1}.jpg'.format(keyword1 ,i)) 
    image1 = image1.resize((256, 256), Image. ANTIALIAS)
    image1 = image1.save(path + '\{0}_{1}.jpg'.format(keyword1 ,i))

# %%
import os
list_of_files = sorted( filter( lambda x: os.path.isfile(os.path.join(".", x)),os.listdir(".") ) )
for file_name in list_of_files:
    print(file_name)
print(files)

# %%
for i in range(1000):
    urllib.request.urlretrieve(urls_dogs[i],path + '\{0}_{1}.jpg'.format(keyword1 ,i))
    image1 = Image.open(path + '\{0}_{1}.jpg'.format(keyword1 ,i)) 
    image1 = image1.resize((256, 256), Image. ANTIALIAS)
    image1 = image1.save(path + '\{0}_{1}.jpg'.format(keyword1 ,i))

    urllib.request.urlretrieve(urls_cats[i],path + '\{0}_{1}.jpg'.format(keyword2 ,i))
    image2 = Image.open(path + '\{0}_{1}.jpg'.format(keyword2, i)) 
    image2 = image2.resize((256, 256), Image. ANTIALIAS)
    image2 = image2.save(path + '\{0}_{1}.jpg'.format(keyword2, i))

    urllib.request.urlretrieve(urls_apes[i],path + '\{0}_{1}.jpg'.format(keyword3 ,i))
    image3 = Image.open(path + '\{0}_{1}.jpg'.format(keyword3, i))
    image3 = image3.resize((256, 256), Image. ANTIALIAS)
    image3 = image3.save(path + '\{0}_{1}.jpg'.format(keyword3, i))


def dataloader():
datagen = ImageDataGenerator(rescale=1./255)
data_directory = '/content/drive/MyDrive/DSSS_9/train'
train_data = datagen.flow_from_directory(directory=data_directory,
                                        target_size=(256, 256),
                                        validation_split=0.8,
                                        class_mode='categorical',
                                        batch_size=32)

val_datagen = ImageDataGenerator(rescale=1./255)
val_data = val_datagen.flow_from_directory(directory=data_directory,
                                           target_size=(256, 256),
                                           validation_split=0.1,
                                           class_mode='categorical',
                                           batch_size=32)

test_datagen = ImageDataGenerator(rescale=1./255)
test_data = test_datagen.flow_from_directory(directory=data_directory,
                                             target_size=(256, 256),
                                             validation_split=0.1,
                                             class_mode='categorical',
                                             batch_size=32)

# %%
for i in range(1000):
    urllib.request.urlretrieve(urls_dogs[i], '/content/drive/MyDrive/DSSS_9/{0}_{1}.jpg'.format(keyword1 ,i))

for i in range(1000):
    for j in range(1000):
        image1 = Image.open('/content/drive/MyDrive/DSSS_9/{0}_{1}.jpg'.format(keyword1, 0+j)) 
        image1 = image1.resize((256, 256), Image. ANTIALIAS)
        image1 = image1.save('/content/drive/MyDrive/DSSS_9/{0}_{1}.jpg'.format(keyword1, 0+j))

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(3, 3, figsize=(8, 8))

for i in range(3):
    for j in range(3):
        image1 = Image.open(path + '\{0}_{1}.jpg'.format(keyword1, 0+j)) 
        image1 = image1.resize((256, 256))
        ax[0, j].imshow(image1)
        ax[0, j].set_title(keyword1 + f'_{1 + j}')

        image2 = Image.open(path + '\{0}_{1}.jpg'.format(keyword2, 0+j)) 
        image2 = image2.resize((256, 256))
        ax[1, j].imshow(image2)
        ax[1, j].set_title(keyword2 + f'_{1 + j}')

        image3 = Image.open(path + '\{0}_{1}.jpg'.format(keyword3, 0+j)) 
        image3 = image3.resize((256, 256))
        ax[2, j].imshow(image3)
        ax[2, j].set_title(keyword3 + f'_{1 + j}')

        ax[i, j].set_xticks([])
        ax[i, j].set_yticks([])

# %%
personal_token = '5854608172:AAFcTPnDUk0ATkaJV3lXpxg1WQcGqhfC6y4'

# %%
ping_url = 'https://api.telegram.org/bot'+str(personal_token)+'/getUpdates'
response = requests.get(ping_url).json()
response

# %%
chat_id = response['result'][0]['message']['chat']['id']
chat_id
# Out:
# 1194575664

# %%
ping_url = 'https://api.telegram.org/bot'+str(personal_token)+'/sendMessage?'+\
            'chat_id='+str(chat_id)+\
            '&parse_mode=Markdown'+\
            '&text='+ 'Hello'

response = requests.get(ping_url)

# %%
import tensorflow as tf
from tensorflow import keras
import tensorflow_datasets as tfds

# %%
def get_model():
    model = keras.Sequential()
    model.add(keras.layers.Dense(1, input_dim=784))
    model.compile(
        optimizer=keras.optimizers.RMSprop(learning_rate=0.1),
        loss="mean_squared_error",
        metrics=["mean_absolute_error"],
    )
    return model

# %%
ds = os.listdir(".")
ds

# %%
cd /content/drive/MyDrive/DSSS_9
# Out:
# /content

# %%
import tensorflow as tf
import glob
img_height = 256
img_width = 256
data_directory = '/content/drive/MyDrive/DSSS_9'
batch_size = 32
x_train = glob.glob(os.path.join(data_directory,"*.jpg"))

# %%
# import os

# X = []
# y = []
# base_dir = '/content/drive/MyDrive/DSSS_9'
# for f in sorted(os.listdir(base_dir)):
#     if os.path.isdir(base_dir+f):
#         print(f"{f} is a target class")
#         for i in sorted(os.listdir(base_dir+f)):
#             print(f"{i} is an input image path")
#             X.append(base_dir+f+'/'+i)
#             y.append(f)
# print(X)
# print(y)
# Out:
# []
# []

# %%
import tensorflow as tf
import random
img_height = 256
img_width = 256
data_directory = '/content/drive/MyDrive/DSSS_9'
batch_size = 32
(train_ds) = tf.keras.utils.image_dataset_from_directory(
   data_directory,
   validation_split=0.2,
   subset="training",
   seed=42, 
   image_size=(img_height, img_width),
   batch_size=batch_size)

random.shuffle(x_train)

(test_ds) = tf.keras.utils.image_dataset_from_directory(
   data_directory,
   validation_split=0.8,
   subset="validation",
   seed=42, 
   image_size=(img_height, img_width),
   batch_size=batch_size)

# y_train = []
# y_val = []

# for i in x_train:
#   c = i.split('\\')[-1].split('_')[0]
#   y_train.append(c)

# for i in x_val:
#   c = i.split('\\')[-1].split('_')[0]
#   y_val.append(c)


#(x_test, y_test)

#x_train = x_train.reshape(-1, 784).astype("float32") / 255.0
#x_test = x_test.reshape(-1, 784).astype("float32") / 255.0

# Limit the data to 1000 samples
# x_train = x_train[:1000]
# y_train = y_train[:1000]
# x_test = x_test[:1000]
# y_test = y_test[:1000]
# Out:
# Found 30 files belonging to 1 classes.
# Using 24 files for training.
# Found 30 files belonging to 1 classes.
# Using 24 files for validation.

# %%
class BotCallback(tf.keras.callbacks.Callback):
    def __init__(self,personal_token):
        self.personal_token = personal_token
        self.ping_url = 'https://api.telegram.org/bot'+str(self.personal_token)+'/getUpdates'
        self.response = requests.get(self.ping_url).json()
        self.chat_id = self.response['result'][0]['message']['chat']['id']

    def send_message(self,message):
        self.ping_url = 'https://api.telegram.org/bot'+str(self.personal_token)+'/sendMessage?'+\
                        'chat_id='+str(self.chat_id)+\
                        '&parse_mode=Markdown'+\
                        '&text='+message
        self.response = requests.get(self.ping_url)
        return self.ping_url

    def on_train_begin(self, epoch_logs=None):
        keys = list(epoch_logs.keys())
        self.send_message("Starting training; got log keys: {}".format(keys))
    
    def on_train_end(self, epoch_logs=None):
        keys = list(epoch_logs.keys())
        self.send_message("Stop training; got log keys: {}".format(keys))

    def on_epoch_begin(self, epoch, epoch_logs=None):
        keys = list(epoch_logs.keys())
        self.send_message("Start epoch {}".format(epoch))

    def on_epoch_end(self, epoch, epoch_logs = None):
        # TODO
        keys = list(epoch_logs.keys())
        self.send_message("End Epoch: {}".format(epoch))
        pass

# %%
model = get_model()
model.fit(
    x_train,
    y_train,
    batch_size=128,
    epochs=1,
    verbose=0,
    validation_split=0.5,
    callbacks=[BotCallback('5854608172:AAFcTPnDUk0ATkaJV3lXpxg1WQcGqhfC6y4')],
)

res = model.evaluate(
    x_test, y_test, batch_size=128, verbose=0, callbacks=[BotCallback('5854608172:AAFcTPnDUk0ATkaJV3lXpxg1WQcGqhfC6y4')]
)

res = model.predict(x_test, batch_size=128, callbacks=[BotCallback('5854608172:AAFcTPnDUk0ATkaJV3lXpxg1WQcGqhfC6y4')])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-73-2e9dd66abad4> in <module>
#       7     verbose=0,
#       8     validation_split=0.5,
# ----> 9     callbacks=[BotCallback('5854608172:AAFcTPnDUk0ATkaJV3lXpxg1WQcGqhfC6y4')],
#      10 )
#      11
#
# <ipython-input-60-c1d488cbe285> in __init__(self, personal_token)
#       4         self.ping_url = 'https://api.telegram.org/bot'+str(self.personal_token)+'/getUpdates'
#       5         self.response = requests.get(self.ping_url).json()
# ----> 6         self.chat_id = self.response['result'][0]['message']['chat']['id']
#       7
#       8     def send_message(self,message):
#
# IndexError: list index out of range

# %%
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %%
model = ResNet50(weights='imagenet')
for i in range (10):
  img_path = '{0}_{1}.jpg'.format(keyword1 ,i)
  img = image.load_img(img_path, target_size=(224, 224))
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
  x = preprocess_input(x)

  preds = model.predict(x)

#print('Predicted:', decode_predictions(preds)[0])
model.summary()

# %%
opt1 = tf.keras.optimizers.SGD(learning_rate=1)
adam = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.975, decay=2e-06, nesterov=True)

model.compile(optimizer=adam,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])

# %%
model.fit(x, epochs=10)

# %%
import matplotlib.pyplot as plotter_lib
import numpy as np
import PIL as image_lib
import tensorflow as tflow
from keras.layers.core import Dense,Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam

# %%
import pathlib
#dataset = 'https://drive.google.com/drive/my-drive'
#directory = tf.keras.utils.get_file('images', origin=demo_dataset, untar=True)
directory = '/content/drive/MyDrive/DSSS_9'
data_directory = pathlib.Path(directory)
data_directory
# Out:
# PosixPath('/content/drive/MyDrive/DSSS_9')

# %%
img_height,img_width=224,224
batch_size=32
train_ds = tflow.keras.preprocessing.image_dataset_from_directory(
  data_directory,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 30 files belonging to 1 classes.
# Using 24 files for training.

# %%
validation_ds = tflow.keras.preprocessing.image_dataset_from_directory(
  data_directory,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 30 files belonging to 1 classes.
# Using 6 files for validation.

# %%
import matplotlib.pyplot as plotter_lib
plotter_lib.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for var in range(6):
    ax = plt.subplot(3, 3, var + 1)
    plotter_lib.imshow(images[var].numpy().astype("uint8"))
    plotter_lib.axis("off")

# %%
resnet_model = Sequential()
pretrained_model= tf.keras.applications.ResNet50(include_top=False,
                   input_shape=(224,224,3),
                   pooling='avg',classes=5,
                   weights='imagenet')

for each_layer in pretrained_model.layers:
        each_layer.trainable=False
resnet_model.add(pretrained_model)

# %%
resnet_model.compile(optimizer=Adam(lr=0.001),loss='categorical_crossentropy',metrics=['accuracy'])

# %%
history = resnet_model.fit(train_ds, validation_data=validation_ds, epochs=10)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-116-79b9304328cb> in <module>
# ----> 1 history = resnet_model.fit(train_ds, validation_data=validation_ds, epochs=10)
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in tf__train_function(iterator)
#      13                 try:
#      14                     do_return = True
# ---> 15                     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
# ...
